# %%
# Dependencies and Setup

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_weather_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city.replace(" ","+") + "&appid=" + weather_api_key
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_weather_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carutapera
# Processing Record 2 of Set 1 | klyuchi
# Processing Record 3 of Set 1 | sinop
# Processing Record 4 of Set 1 | isafjordur
# Processing Record 5 of Set 1 | beni mellal
# Processing Record 6 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 7 of Set 1 | utrik
# Processing Record 8 of Set 1 | wailua homesteads
# Processing Record 9 of Set 1 | edinburgh of the seven seas
# Processing Record 10 of Set 1 | shangri-la
# City not found. Skipping...
# Processing Record 11 of Set 1 | semirara
# Processing Record 12 of Set 1 | amarillo
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | afega
# Processing Record 15 of Set 1 | tual
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | calbe
# Processing Record 18 of Set 1 | iskateley
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | kerema
# Processing Record 21 of Set 1 | thinadhoo
# Processing Record 22 of Set 1 | bargara
# City not found. Skipping...
# Processing Record 23 of Set 1 | blackmans bay
# Processing Record 24 of Set 1 | egilsstadir
# Processing Record 25 of Set 1 | polyarnyy
# Processing Record 26 of Set 1 | iqaluit
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | at taj
# Processing Record 30 of Set 1 | port mathurin
# Processing Record 31 of Set 1 | port lincoln
# Processing Record 32 of Set 1 | oranjestad
# Processing Record 33 of Set 1 | adamstown
# Processing Record 34 of Set 1 | fada
# Processing Record 35 of Set 1 | olonkinbyen
# Processing Record 36 of Set 1 | alice springs
# Processing Record 37 of Set 1 | yellowknife
# Processing Record 38 of Set 1 | san patricio
# Processing Record 39 of Set 1 | la mure
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | saipan
# Processing Record 42 of Set 1 | waitangi
# Processing Record 43 of Set 1 | gonzalez
# Processing Record 44 of Set 1 | la romana
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | kingston
# Processing Record 47 of Set 1 | atafu village
# Processing Record 48 of Set 1 | kudahuvadhoo
# Processing Record 49 of Set 1 | queenstown
# Processing Record 50 of Set 1 | bomdila
# Processing Record 0 of Set 2 | borogontsy
# Processing Record 1 of Set 2 | laascaanood
# Processing Record 2 of Set 2 | flying fish cove
# Processing Record 3 of Set 2 | chonchi
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | papatowai
# Processing Record 6 of Set 2 | kidal
# Processing Record 7 of Set 2 | vernon
# Processing Record 8 of Set 2 | west island
# Processing Record 9 of Set 2 | pachino
# Processing Record 10 of Set 2 | ipira
# Processing Record 11 of Set 2 | bilibino
# Processing Record 12 of Set 2 | mil'kovo
# Processing Record 13 of Set 2 | laguna
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | kuressaare
# Processing Record 16 of Set 2 | malanville
# Processing Record 17 of Set 2 | qaqortoq
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | puerto natales
# Processing Record 20 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 21 of Set 2 | serres
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | lai chau
# Processing Record 24 of Set 2 | kolobrzeg
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | vilyuchinsk
# Processing Record 27 of Set 2 | kailua-kona
# Processing Record 28 of Set 2 | mahuta
# Processing Record 29 of Set 2 | cabinda
# Processing Record 30 of Set 2 | whitehorse
# Processing Record 31 of Set 2 | north shore
# Processing Record 32 of Set 2 | novaya ladoga
# Processing Record 33 of Set 2 | minas de marcona
# Processing Record 34 of Set 2 | toliara
# Processing Record 35 of Set 2 | ruovesi
# Processing Record 36 of Set 2 | mejit
# Processing Record 37 of Set 2 | kalmunai
# Processing Record 38 of Set 2 | hithadhoo
# Processing Record 39 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 2 | al majaridah
# Processing Record 41 of Set 2 | muisne
# Processing Record 42 of Set 2 | anadyr
# Processing Record 43 of Set 2 | susuman
# Processing Record 44 of Set 2 | wotho
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | zephyrhills
# Processing Record 47 of Set 2 | charleston
# Processing Record 48 of Set 2 | filadelfia
# Processing Record 49 of Set 2 | saldanha
# Processing Record 0 of Set 3 | batticaloa
# Processing Record 1 of Set 3 | fremantle
# Processing Record 2 of Set 3 | kapuskasing
# Processing Record 3 of Set 3 | eyl
# Processing Record 4 of Set 3 | rongelap
# Processing Record 5 of Set 3 | usinsk
# Processing Record 6 of Set 3 | badger
# Processing Record 7 of Set 3 | avarua
# Processing Record 8 of Set 3 | mount isa
# Processing Record 9 of Set 3 | yangor
# City not found. Skipping...
# Processing Record 10 of Set 3 | devonport
# Processing Record 11 of Set 3 | al jahra'
# Processing Record 12 of Set 3 | margaret river
# Processing Record 13 of Set 3 | necochea
# Processing Record 14 of Set 3 | sao gabriel da cachoeira
# Processing Record 15 of Set 3 | salym
# Processing Record 16 of Set 3 | boa vista
# Processing Record 17 of Set 3 | mitrofanovka
# Processing Record 18 of Set 3 | orsk
# Processing Record 19 of Set 3 | bandarban
# Processing Record 20 of Set 3 | prineville
# Processing Record 21 of Set 3 | vila velha
# Processing Record 22 of Set 3 | taulaga
# Processing Record 23 of Set 3 | al jawf
# Processing Record 24 of Set 3 | hermanus
# Processing Record 25 of Set 3 | invercargill
# Processing Record 26 of Set 3 | grand-bassam
# Processing Record 27 of Set 3 | weihai
# Processing Record 28 of Set 3 | roma
# Processing Record 29 of Set 3 | orsa
# Processing Record 30 of Set 3 | pisco
# Processing Record 31 of Set 3 | bima
# Processing Record 32 of Set 3 | inhambane
# Processing Record 33 of Set 3 | kuanda
# Processing Record 34 of Set 3 | keflavik
# Processing Record 35 of Set 3 | kharabali
# Processing Record 36 of Set 3 | ushuaia
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | broken hill
# Processing Record 39 of Set 3 | namibe
# Processing Record 40 of Set 3 | mathba
# Processing Record 41 of Set 3 | chimore
# Processing Record 42 of Set 3 | shingu
# Processing Record 43 of Set 3 | high point
# Processing Record 44 of Set 3 | sorong
# Processing Record 45 of Set 3 | dhidhdhoo
# Processing Record 46 of Set 3 | kulia village
# City not found. Skipping...
# Processing Record 47 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 48 of Set 3 | longyearbyen
# Processing Record 49 of Set 3 | sao jose da coroa grande
# Processing Record 0 of Set 4 | itoman
# Processing Record 1 of Set 4 | gavrilov-yam
# Processing Record 2 of Set 4 | lubao
# Processing Record 3 of Set 4 | stanley
# Processing Record 4 of Set 4 | mstsislaw
# Processing Record 5 of Set 4 | brisas de zicatela
# Processing Record 6 of Set 4 | vila franca do campo
# Processing Record 7 of Set 4 | moshi
# Processing Record 8 of Set 4 | dudinka
# Processing Record 9 of Set 4 | kangal
# Processing Record 10 of Set 4 | enewetak
# Processing Record 11 of Set 4 | quang ngai
# Processing Record 12 of Set 4 | harper
# Processing Record 13 of Set 4 | mhamid
# Processing Record 14 of Set 4 | tomatlan
# Processing Record 15 of Set 4 | olyokminsk
# Processing Record 16 of Set 4 | castillos
# Processing Record 17 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 18 of Set 4 | pont rouge
# Processing Record 19 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 20 of Set 4 | puerto baquerizo moreno
# Processing Record 21 of Set 4 | bikenibeu village
# Processing Record 22 of Set 4 | alesund
# Processing Record 23 of Set 4 | illizi
# Processing Record 24 of Set 4 | kayyerkan
# Processing Record 25 of Set 4 | nouadhibou
# Processing Record 26 of Set 4 | qui nhon
# Processing Record 27 of Set 4 | pemba
# Processing Record 28 of Set 4 | al abyar
# Processing Record 29 of Set 4 | paita
# Processing Record 30 of Set 4 | artigas
# Processing Record 31 of Set 4 | greymouth
# Processing Record 32 of Set 4 | carauari
# Processing Record 33 of Set 4 | charlottetown
# Processing Record 34 of Set 4 | hammerfest
# Processing Record 35 of Set 4 | fale old settlement
# Processing Record 36 of Set 4 | juuka
# Processing Record 37 of Set 4 | flin flon
# Processing Record 38 of Set 4 | howrah
# Processing Record 39 of Set 4 | xinyuan
# Processing Record 40 of Set 4 | phalodi
# Processing Record 41 of Set 4 | jayapura
# Processing Record 42 of Set 4 | helena
# Processing Record 43 of Set 4 | nanga eboko
# Processing Record 44 of Set 4 | kalabagh
# Processing Record 45 of Set 4 | lahaina
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | liberal
# Processing Record 48 of Set 4 | guarda
# Processing Record 49 of Set 4 | awjilah
# Processing Record 0 of Set 5 | jamestown
# Processing Record 1 of Set 5 | amarpur
# Processing Record 2 of Set 5 | zheshart
# Processing Record 3 of Set 5 | guerrero negro
# Processing Record 4 of Set 5 | cockburn town
# Processing Record 5 of Set 5 | prince rupert
# Processing Record 6 of Set 5 | college
# Processing Record 7 of Set 5 | labrador city
# Processing Record 8 of Set 5 | uturoa
# Processing Record 9 of Set 5 | kapa'a
# Processing Record 10 of Set 5 | udachny
# Processing Record 11 of Set 5 | san luis de la loma
# Processing Record 12 of Set 5 | abalak
# Processing Record 13 of Set 5 | masuguru
# Processing Record 14 of Set 5 | yuzhno-kurilsk
# Processing Record 15 of Set 5 | ponta delgada
# Processing Record 16 of Set 5 | kyshtovka
# Processing Record 17 of Set 5 | tidjikja
# Processing Record 18 of Set 5 | sokoni
# Processing Record 19 of Set 5 | gwanda
# Processing Record 20 of Set 5 | timbuktu
# Processing Record 21 of Set 5 | selfoss
# Processing Record 22 of Set 5 | nasir
# Processing Record 23 of Set 5 | zemoura
# Processing Record 24 of Set 5 | east london
# Processing Record 25 of Set 5 | le port
# Processing Record 26 of Set 5 | chernushka
# Processing Record 27 of Set 5 | coxen hole
# Processing Record 28 of Set 5 | ketchikan
# Processing Record 29 of Set 5 | fortaleza
# Processing Record 30 of Set 5 | brookings
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | ngaoundere
# Processing Record 33 of Set 5 | sukhobezvodnoye
# Processing Record 34 of Set 5 | lazaro cardenas
# Processing Record 35 of Set 5 | santa ines
# Processing Record 36 of Set 5 | nafpaktos
# Processing Record 37 of Set 5 | usogorsk
# Processing Record 38 of Set 5 | turkmenbasy
# Processing Record 39 of Set 5 | lebu
# Processing Record 40 of Set 5 | fort bragg
# Processing Record 41 of Set 5 | touros
# Processing Record 42 of Set 5 | sakaiminato
# Processing Record 43 of Set 5 | menongue
# Processing Record 44 of Set 5 | sinabang
# Processing Record 45 of Set 5 | mata-utu
# Processing Record 46 of Set 5 | la sarre
# Processing Record 47 of Set 5 | new norfolk
# Processing Record 48 of Set 5 | gvardeysk
# Processing Record 49 of Set 5 | lisala
# Processing Record 0 of Set 6 | sakata
# Processing Record 1 of Set 6 | bom jardim
# Processing Record 2 of Set 6 | kavieng
# Processing Record 3 of Set 6 | espumoso
# Processing Record 4 of Set 6 | afaahiti
# Processing Record 5 of Set 6 | yanchep
# Processing Record 6 of Set 6 | callao
# Processing Record 7 of Set 6 | porto de moz
# Processing Record 8 of Set 6 | tadine
# Processing Record 9 of Set 6 | grants
# Processing Record 10 of Set 6 | derebucak
# Processing Record 11 of Set 6 | ouellah
# City not found. Skipping...
# Processing Record 12 of Set 6 | mangai
# Processing Record 13 of Set 6 | morehead city
# Processing Record 14 of Set 6 | baharampur
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | lihue
# Processing Record 17 of Set 6 | ingeniero jacobacci
# Processing Record 18 of Set 6 | kodiak
# Processing Record 19 of Set 6 | huarmey
# Processing Record 20 of Set 6 | punta arenas
# Processing Record 21 of Set 6 | freetown
# Processing Record 22 of Set 6 | sydney mines
# Processing Record 23 of Set 6 | thanh pho uong bi
# Processing Record 24 of Set 6 | arboletes
# Processing Record 25 of Set 6 | chai nat
# Processing Record 26 of Set 6 | pointe-noire
# Processing Record 27 of Set 6 | constantia
# Processing Record 28 of Set 6 | knyaze-volkonskoye
# Processing Record 29 of Set 6 | kalemie
# Processing Record 30 of Set 6 | vadso
# Processing Record 31 of Set 6 | ixtapa
# Processing Record 32 of Set 6 | remire-montjoly
# Processing Record 33 of Set 6 | kontagora
# Processing Record 34 of Set 6 | dogondoutchi
# Processing Record 35 of Set 6 | la'ie
# Processing Record 36 of Set 6 | cooma
# Processing Record 37 of Set 6 | colonia
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | georgetown
# Processing Record 40 of Set 6 | zeya
# Processing Record 41 of Set 6 | badr hunayn
# Processing Record 42 of Set 6 | tachilek
# City not found. Skipping...
# Processing Record 43 of Set 6 | tazovsky
# Processing Record 44 of Set 6 | midvagur
# Processing Record 45 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 46 of Set 6 | st. john's
# Processing Record 47 of Set 6 | raton
# Processing Record 48 of Set 6 | nampula
# Processing Record 49 of Set 6 | mar del plata
# Processing Record 0 of Set 7 | tura
# Processing Record 1 of Set 7 | sitka
# Processing Record 2 of Set 7 | howard springs
# Processing Record 3 of Set 7 | hawaiian paradise park
# Processing Record 4 of Set 7 | hafnarfjordur
# Processing Record 5 of Set 7 | la passe
# Processing Record 6 of Set 7 | morant bay
# Processing Record 7 of Set 7 | inari
# Processing Record 8 of Set 7 | salalah
# Processing Record 9 of Set 7 | zouerate
# Processing Record 10 of Set 7 | bardai
# Processing Record 11 of Set 7 | djambala
# Processing Record 12 of Set 7 | mili
# Processing Record 13 of Set 7 | aasiaat
# Processing Record 14 of Set 7 | loralai
# Processing Record 15 of Set 7 | woolgoolga
# Processing Record 16 of Set 7 | lethem
# Processing Record 17 of Set 7 | naantali
# Processing Record 18 of Set 7 | dalandzadgad
# Processing Record 19 of Set 7 | gadani
# Processing Record 20 of Set 7 | cerritos
# Processing Record 21 of Set 7 | montrose
# Processing Record 22 of Set 7 | gadzhiyevo
# Processing Record 23 of Set 7 | nova sintra
# Processing Record 24 of Set 7 | igarka
# Processing Record 25 of Set 7 | ataq
# Processing Record 26 of Set 7 | detroit lakes
# Processing Record 27 of Set 7 | port alfred
# Processing Record 28 of Set 7 | crane
# Processing Record 29 of Set 7 | mount gambier
# Processing Record 30 of Set 7 | manismata
# Processing Record 31 of Set 7 | upata
# Processing Record 32 of Set 7 | nuku'alofa
# Processing Record 33 of Set 7 | acapulco de juarez
# Processing Record 34 of Set 7 | hounde
# Processing Record 35 of Set 7 | durres
# Processing Record 36 of Set 7 | dolores
# Processing Record 37 of Set 7 | cobija
# Processing Record 38 of Set 7 | ust-nera
# Processing Record 39 of Set 7 | harnoli
# Processing Record 40 of Set 7 | tsiombe
# Processing Record 41 of Set 7 | madinat sittah uktubar
# Processing Record 42 of Set 7 | ciudad lazaro cardenas
# Processing Record 43 of Set 7 | nuuk
# Processing Record 44 of Set 7 | arraial do cabo
# Processing Record 45 of Set 7 | sandnessjoen
# Processing Record 46 of Set 7 | diapaga
# Processing Record 47 of Set 7 | warrnambool
# Processing Record 48 of Set 7 | oranjemund
# Processing Record 49 of Set 7 | okha
# Processing Record 0 of Set 8 | riberalta
# Processing Record 1 of Set 8 | takamaka
# City not found. Skipping...
# Processing Record 2 of Set 8 | bologoye-4
# City not found. Skipping...
# Processing Record 3 of Set 8 | yeniseysk
# Processing Record 4 of Set 8 | kaa-khem
# Processing Record 5 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 6 of Set 8 | itamaraca
# Processing Record 7 of Set 8 | apache junction
# Processing Record 8 of Set 8 | nansio
# Processing Record 9 of Set 8 | mwinilunga
# Processing Record 10 of Set 8 | santa cruz
# Processing Record 11 of Set 8 | happy valley-goose bay
# Processing Record 12 of Set 8 | kourou
# Processing Record 13 of Set 8 | liberia
# Processing Record 14 of Set 8 | arvayheer
# Processing Record 15 of Set 8 | zakamensk
# Processing Record 16 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 17 of Set 8 | cradock
# Processing Record 18 of Set 8 | aykhal
# Processing Record 19 of Set 8 | pskov
# Processing Record 20 of Set 8 | pasuquin
# Processing Record 21 of Set 8 | penaranda de bracamonte
# Processing Record 22 of Set 8 | keningau
# Processing Record 23 of Set 8 | chingirlau
# Processing Record 24 of Set 8 | rancho palos verdes
# Processing Record 25 of Set 8 | praia
# Processing Record 26 of Set 8 | veraval
# Processing Record 27 of Set 8 | carnarvon
# Processing Record 28 of Set 8 | cadale
# Processing Record 29 of Set 8 | butembo
# Processing Record 30 of Set 8 | blagoevgrad
# Processing Record 31 of Set 8 | mamuju
# Processing Record 32 of Set 8 | tralee
# Processing Record 33 of Set 8 | zhezqazghan
# Processing Record 34 of Set 8 | porto belo
# Processing Record 35 of Set 8 | grand rapids
# Processing Record 36 of Set 8 | zhytkavichy
# Processing Record 37 of Set 8 | cestos city
# Processing Record 38 of Set 8 | hirara
# Processing Record 39 of Set 8 | margate
# Processing Record 40 of Set 8 | naze
# Processing Record 41 of Set 8 | pangody
# Processing Record 42 of Set 8 | oualidia
# City not found. Skipping...
# Processing Record 43 of Set 8 | vigan
# Processing Record 44 of Set 8 | hamamatsu
# Processing Record 45 of Set 8 | cafayate
# Processing Record 46 of Set 8 | horta
# Processing Record 47 of Set 8 | ambon
# Processing Record 48 of Set 8 | iwanai
# Processing Record 49 of Set 8 | swakopmund
# Processing Record 0 of Set 9 | kapsan-up
# Processing Record 1 of Set 9 | sao joao da barra
# Processing Record 2 of Set 9 | bubaque
# Processing Record 3 of Set 9 | mooirivier
# Processing Record 4 of Set 9 | cabo san lucas
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | gaspe
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | illapel
# Processing Record 9 of Set 9 | slave lake
# Processing Record 10 of Set 9 | hadibu
# Processing Record 11 of Set 9 | opuwo
# Processing Record 12 of Set 9 | gebeit
# Processing Record 13 of Set 9 | rio preto da eva
# Processing Record 14 of Set 9 | bhamo
# Processing Record 15 of Set 9 | tofol
# Processing Record 16 of Set 9 | ta`u
# Processing Record 17 of Set 9 | ephrata
# Processing Record 18 of Set 9 | ubari
# Processing Record 19 of Set 9 | waitara
# Processing Record 20 of Set 9 | mogadishu
# Processing Record 21 of Set 9 | nagqu
# Processing Record 22 of Set 9 | lanzhou
# Processing Record 23 of Set 9 | jabat
# Processing Record 24 of Set 9 | chivilcoy
# Processing Record 25 of Set 9 | kodinsk
# Processing Record 26 of Set 9 | acarau
# Processing Record 27 of Set 9 | les anglais
# Processing Record 28 of Set 9 | motygino
# Processing Record 29 of Set 9 | santa ana
# Processing Record 30 of Set 9 | muravlenko
# Processing Record 31 of Set 9 | terbanggi besar
# Processing Record 32 of Set 9 | suva
# Processing Record 33 of Set 9 | cova figueira
# Processing Record 34 of Set 9 | gaiman
# Processing Record 35 of Set 9 | chake chake
# Processing Record 36 of Set 9 | lompoc
# Processing Record 37 of Set 9 | prince george
# Processing Record 38 of Set 9 | angra dos reis
# Processing Record 39 of Set 9 | regente feijo
# Processing Record 40 of Set 9 | boende
# Processing Record 41 of Set 9 | kerikeri
# Processing Record 42 of Set 9 | sharm el-sheikh
# Processing Record 43 of Set 9 | nova vicosa
# Processing Record 44 of Set 9 | weno
# Processing Record 45 of Set 9 | vangaindrano
# Processing Record 46 of Set 9 | kargopol'
# Processing Record 47 of Set 9 | mitsamiouli
# Processing Record 48 of Set 9 | arno
# Processing Record 49 of Set 9 | quellon
# Processing Record 0 of Set 10 | sihanoukville
# Processing Record 1 of Set 10 | tshabong
# Processing Record 2 of Set 10 | bourg-saint-andeol
# Processing Record 3 of Set 10 | urucara
# Processing Record 4 of Set 10 | san julian
# Processing Record 5 of Set 10 | al mithnab
# City not found. Skipping...
# Processing Record 6 of Set 10 | nicoya
# Processing Record 7 of Set 10 | pacific grove
# Processing Record 8 of Set 10 | port douglas
# Processing Record 9 of Set 10 | sabang
# Processing Record 10 of Set 10 | shuangjiang
# Processing Record 11 of Set 10 | canton
# Processing Record 12 of Set 10 | sechura
# Processing Record 13 of Set 10 | fisterra
# Processing Record 14 of Set 10 | banda aceh
# Processing Record 15 of Set 10 | antsiranana
# Processing Record 16 of Set 10 | aleg
# Processing Record 17 of Set 10 | greeley
# Processing Record 18 of Set 10 | fuyu
# Processing Record 19 of Set 10 | isla aguada
# Processing Record 20 of Set 10 | taltal
# Processing Record 21 of Set 10 | kavaratti
# Processing Record 22 of Set 10 | altai
# Processing Record 23 of Set 10 | fort st. john
# Processing Record 24 of Set 10 | clarkston heights-vineland
# Processing Record 25 of Set 10 | champerico
# Processing Record 26 of Set 10 | kamyshin
# Processing Record 27 of Set 10 | selkirk
# Processing Record 28 of Set 10 | touggourt
# Processing Record 29 of Set 10 | whakatane
# Processing Record 30 of Set 10 | chicxulub puerto
# City not found. Skipping...
# Processing Record 31 of Set 10 | losal
# Processing Record 32 of Set 10 | sikasso
# Processing Record 33 of Set 10 | haiku-pauwela
# Processing Record 34 of Set 10 | gorontalo
# Processing Record 35 of Set 10 | mizhhirya
# Processing Record 36 of Set 10 | malmesbury
# Processing Record 37 of Set 10 | usakos
# Processing Record 38 of Set 10 | yorkton
# Processing Record 39 of Set 10 | cururupu
# Processing Record 40 of Set 10 | puerto deseado
# Processing Record 41 of Set 10 | kill devil hills
# Processing Record 42 of Set 10 | revda
# Processing Record 43 of Set 10 | ubinskoye
# Processing Record 44 of Set 10 | bam
# Processing Record 45 of Set 10 | belyy yar
# Processing Record 46 of Set 10 | bizerte
# Processing Record 47 of Set 10 | hilo
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 0 of Set 11 | qa'en
# Processing Record 1 of Set 11 | ierapetra
# Processing Record 2 of Set 11 | porbandar
# Processing Record 3 of Set 11 | ishigaki
# Processing Record 4 of Set 11 | fort mcmurray
# Processing Record 5 of Set 11 | bojnurd
# Processing Record 6 of Set 11 | barra dos coqueiros
# Processing Record 7 of Set 11 | ivins
# Processing Record 8 of Set 11 | jining
# Processing Record 9 of Set 11 | broome
# Processing Record 10 of Set 11 | tabou
# Processing Record 11 of Set 11 | ormara
# Processing Record 12 of Set 11 | horncastle
# Processing Record 13 of Set 11 | gazli
# Processing Record 14 of Set 11 | narasannapeta
# Processing Record 15 of Set 11 | hornell
# Processing Record 16 of Set 11 | el charco
# Processing Record 17 of Set 11 | santa cruz de tenerife
# Processing Record 18 of Set 11 | kaiapoi
# Processing Record 19 of Set 11 | vallenar
# Processing Record 20 of Set 11 | xique xique
# Processing Record 21 of Set 11 | sur
# Processing Record 22 of Set 11 | chipinge
# Processing Record 23 of Set 11 | totness
# Processing Record 24 of Set 11 | vorgashor
# Processing Record 25 of Set 11 | serdar
# Processing Record 26 of Set 11 | ukholovo
# Processing Record 27 of Set 11 | ivdel'
# Processing Record 28 of Set 11 | ekpoma
# Processing Record 29 of Set 11 | dampit
# Processing Record 30 of Set 11 | nyurba
# Processing Record 31 of Set 11 | kununurra
# Processing Record 32 of Set 11 | tefe
# Processing Record 33 of Set 11 | rozdilna
# Processing Record 34 of Set 11 | aitape
# Processing Record 35 of Set 11 | seven pagodas
# Processing Record 36 of Set 11 | cernavoda
# Processing Record 37 of Set 11 | novodvinsk
# Processing Record 38 of Set 11 | belozersk
# Processing Record 39 of Set 11 | shagonar
# Processing Record 40 of Set 11 | catio
# Processing Record 41 of Set 11 | lambton shores
# City not found. Skipping...
# Processing Record 42 of Set 11 | zag
# Processing Record 43 of Set 11 | ocean shores
# Processing Record 44 of Set 11 | gisborne
# Processing Record 45 of Set 11 | bozeman
# Processing Record 46 of Set 11 | akureyri
# Processing Record 47 of Set 11 | yelizovo
# Processing Record 48 of Set 11 | baker city
# Processing Record 49 of Set 11 | qarazhal
# Processing Record 0 of Set 12 | tinana
# City not found. Skipping...
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | saint-pierre
# Processing Record 3 of Set 12 | luanda
# Processing Record 4 of Set 12 | sampit
# Processing Record 5 of Set 12 | iacu
# Processing Record 6 of Set 12 | den burg
# Processing Record 7 of Set 12 | pratt
# Processing Record 8 of Set 12 | onega
# Processing Record 9 of Set 12 | sumberpucung
# Processing Record 10 of Set 12 | holualoa
# Processing Record 11 of Set 12 | mossel bay
# Processing Record 12 of Set 12 | kolokani
# Processing Record 13 of Set 12 | brandfort
# Processing Record 14 of Set 12 | roosevelt
# Processing Record 15 of Set 12 | whitecourt
# Processing Record 16 of Set 12 | barra do bugres
# Processing Record 17 of Set 12 | san lawrenz
# Processing Record 18 of Set 12 | wainwright
# Processing Record 19 of Set 12 | mont-laurier
# Processing Record 20 of Set 12 | tsarevo
# Processing Record 21 of Set 12 | jindabyne
# Processing Record 22 of Set 12 | zuunmod
# Processing Record 23 of Set 12 | 'ayy
# City not found. Skipping...
# Processing Record 24 of Set 12 | balmazujvaros
# Processing Record 25 of Set 12 | vilyuysk
# Processing Record 26 of Set 12 | bimbo
# Processing Record 27 of Set 12 | losice
# Processing Record 28 of Set 12 | wenatchee
# Processing Record 29 of Set 12 | lee acres
# Processing Record 30 of Set 12 | alaghsas
# Processing Record 31 of Set 12 | bannockburn
# Processing Record 32 of Set 12 | anloga
# Processing Record 33 of Set 12 | bandarbeyla
# Processing Record 34 of Set 12 | funafuti
# Processing Record 35 of Set 12 | leninskiy
# Processing Record 36 of Set 12 | trincomalee
# Processing Record 37 of Set 12 | mukalla
# Processing Record 38 of Set 12 | fastovetskaya
# Processing Record 39 of Set 12 | salinopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({
                "City": city,
                "lat": city_lat,
                "Lng": city_lng,
                "Max Temp": city_max_temp,
                "Humidity": city_humidity,
                "Cloudiness": city_clouds,
                "Wind Speed": city_wind,
                "Country": city_country,
                "Date": city_date,
             }, index=range(len(city)))


# Show Record Count
print(city_data_df)
# Out:
#            City     lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 1   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 2   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 3   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 4   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 5   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 6   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 7   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 8   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 9   salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 10  salinopolis -0.6136 -47.3561    298.04        86          96        1.24
#
#    Country        Date
# 0       BR  1682671159
# 1       BR  1682671159
# 2       BR  1682671159
# 3       BR  1682671159
# 4       BR  1682671159
# 5       BR  1682671159
# 6       BR  1682671159
# 7       BR  1682671159
# 8       BR  1682671159
# 9       BR  1682671159
# 10      BR  1682671159

# %%
# Display sample data
city_data_df.head()
# Out:
#           City     lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 1  salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 2  salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 3  salinopolis -0.6136 -47.3561    298.04        86          96        1.24
# 4  salinopolis -0.6136 -47.3561    298.04        86          96        1.24
#
#   Country        Date
# 0      BR  1682671159
# 1      BR  1682671159
# 2      BR  1682671159
# 3      BR  1682671159
# 4      BR  1682671159

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City     lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        salinopolis -0.6136 -47.3561    298.04        86          96
# 1        salinopolis -0.6136 -47.3561    298.04        86          96
# 2        salinopolis -0.6136 -47.3561    298.04        86          96
# 3        salinopolis -0.6136 -47.3561    298.04        86          96
# 4        salinopolis -0.6136 -47.3561    298.04        86          96
#
#          Wind Speed Country        Date
# City_ID
# 0              1.24      BR  1682671159
# 1              1.24      BR  1682671159
# 2              1.24      BR  1682671159
# 3              1.24      BR  1682671159
# 4              1.24      BR  1682671159

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity
plt.scatter(city_data_df["lat"], city_data_df["Humidity"], edgecolors="black", facecolors="skyblue")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["lat"], city_data_df["Cloudiness"], label="Cities")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Define a function to create Linear Regression plots
plot_linear_regression=(city_data_df["lat"], city_data_df["Max Temp"], "Latitude", "Max Temperature")
plot_linear_regression

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE
